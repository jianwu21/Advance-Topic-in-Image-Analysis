# %%
# %matplotlib inline

import numpy as np
import cv2
import matplotlib.pyplot as plt
import skimage
import pickle
import os

from preprocess.process_leaf import process_scan_leaf

# %%
leafscan_dict = pickle.load(open('./train.pickle', 'rb'))
all_classes = leafscan_dict.keys()

# Example for showing the orignal pic
for family in all_classes[:4]:
    for im_id in leafscan_dict.get(family):
        ex_path = os.path.join('./train/', im_id + '.jpg')
        process_scan_leaf(ex_path, output_folder='./')
# Out:
# [leafscan] 61558.jpg a fost procesata de leaf scan complex
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-894db99c00e7> in <module>()
#       6     for im_id in leafscan_dict.get(family):
#       7         ex_path = os.path.join('./train/', im_id + '.jpg')
# ----> 8         process_scan_leaf(ex_path, output_folder='./')
#
# /home/jwu/KU/Advance-Topic-in-Image-Processing/Object_Recognition/preprocess/process_leaf.py in process_scan_leaf(scan_leaf_path, output_folder)
#      29         bgd_model = np.zeros((1, 65), np.float64)
#      30         fgd_model = np.zeros((1, 65), np.float64)
# ---> 31         cv2.grabCut(image, mask, rect, bgd_model, fgd_model, 5, cv2.GC_INIT_WITH_RECT)
#      32         mask2 = np.where((mask == 2) | (mask == 0), 0, 1).astype('uint8')
#      33         image = image * mask2[:, :, np.newaxis]
#
# KeyboardInterrupt:

# %%
image = cv2.imread('./61558.jpg')
plt.imshow(image)

plt.imshow(cv2.resize(image, (100, 100)))
