# %% [markdown]
# Segmentation
# ============

# %%
# %matplotlib inline

import cv2
import numpy
from matplotlib import pyplot as plt

# %%
im = plt.imread('data/DSC_0055.JPG').astype('float32')
plt.imshow(im)
